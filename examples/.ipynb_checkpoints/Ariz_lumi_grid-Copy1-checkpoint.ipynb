# %%
#Attempting to delete all hardcoding from beambeam3d.py and having variables as inputs instead
import numpy as np
from matplotlib import pyplot as plt
import xobjects as xo
import xtrack as xt
import xfieldsdevlumi as xf
import xpart as xp
import time
# Generating sequences

context = xo.ContextCpu()

p0c = 45.6e9
bunch_intensity = 1.7E11
physemit_x = 0.27e-9
physemit_y = 1e-12
beta_x = 19.17
beta_y = 19.17
sigma_z = 3.5e-3
sigma_delta = 8.4E-4
beta_s = sigma_z/sigma_delta
Qx = 269.13
Qy = 267.18
Qs = 0.0025
frev = 11245.5 
nTurn = 3

n_macroparticles = int(100000)
xs_b1 = []
ys_b1 = []
xs_b2 = []
ys_b2 = []
pxs_b1 = []
pys_b1 = []
pxs_b2 = []
pys_b2 = []

pipeline_manager = xt.PipelineManager()
pipeline_manager.add_particles('b1',0)
pipeline_manager.add_particles('b2',0)
pipeline_manager.add_element('IP1')
pipeline_manager.add_element('IP2')

particles_b1 = xp.Particles(_context=context,
    p0c=p0c,
    x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
    px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
    y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
    py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
    zeta=sigma_z*np.random.randn(n_macroparticles),
    delta=sigma_delta*np.random.randn(n_macroparticles),
    weight=bunch_intensity/n_macroparticles
)
particles_b1.init_pipeline('b1')
particles_b2 = xp.Particles(_context=context,
    p0c=p0c,
    x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
    px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
    y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
    py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
    zeta=sigma_z*np.random.randn(n_macroparticles),
    delta=sigma_delta*np.random.randn(n_macroparticles),
    weight=bunch_intensity/n_macroparticles
)
particles_b2.init_pipeline('b2')

#############
# Beam-beam #
#############
slicer = xf.TempSlicer(sigma_z=sigma_z, n_slices=1, mode = 'shatilov')
config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
pipeline_manager=pipeline_manager,
element_name='IP1',
partner_particles_name = 'b2',
slicer=slicer,
update_every=1,
)
config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
pipeline_manager=pipeline_manager,
element_name='IP1',
partner_particles_name = 'b1',
slicer=slicer,
update_every=1,
)

IP2_config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
pipeline_manager=pipeline_manager,
element_name='IP2',
partner_particles_name = 'b2',
slicer=slicer,
update_every=1,
)
IP2_config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
pipeline_manager=pipeline_manager,
element_name='IP2',
partner_particles_name = 'b1',
slicer=slicer,
update_every=1,
)

print('build bb elements...')
bbeam_b1 = xf.BeamBeamBiGaussian3D(
            _context=context,
            other_beam_q0 = particles_b2.q0,
            phi = 0,alpha=0,
            config_for_update = config_for_update_b1,
            flag_numerical_luminosity = 1,
            flag_luminosity = 1,
            n_lumigrid_cells=1500,
            sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
            range_lumigrid_cells = 24,
            n_macroparticles=n_macroparticles,
            nTurn = nTurn,
            update_lumigrid_sum=1
            )
bbeam_b2 = xf.BeamBeamBiGaussian3D(
            _context=context,
            other_beam_q0 = particles_b1.q0,
            phi = 0,alpha=0,
            config_for_update = config_for_update_b2,
            flag_numerical_luminosity = 1,
            flag_luminosity = 1,
            n_lumigrid_cells=1500,
            sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
            range_lumigrid_cells = 24,
            n_macroparticles=n_macroparticles,
            nTurn = nTurn,
            update_lumigrid_sum=1
            )
print(n_macroparticles)
IP2_bbeam_b1 = xf.BeamBeamBiGaussian3D(
            _context=context,
            other_beam_q0 = particles_b2.q0,
            phi = 0,alpha=0,
            config_for_update = IP2_config_for_update_b1,
            flag_numerical_luminosity = 0,
            flag_luminosity = 1,
            update_lumigrid_sum=1)
IP2_bbeam_b2 = xf.BeamBeamBiGaussian3D(
            _context=context,
            other_beam_q0 = particles_b1.q0,
            phi = 0,alpha=0,
            config_for_update = IP2_config_for_update_b2,
            flag_numerical_luminosity= 0,
            flag_luminosity = 1,
            update_lumigrid_sum=1)


#################################################################
# arcs (here they are all the same with half the phase advance) #
#################################################################

arc = xt.LineSegmentMap(
        betx = beta_x,bety = beta_y,
        qx = Qx/2, qy = Qy/2,bets = beta_s, qs=Qs)
#################################################################
# Tracker                                                       #
#################################################################
'''
elements_b1 = [bbeam_b1,arc]
elements_b2 = [bbeam_b2,arc]
element_names_b1 = ['bbeam_b1','arc']
element_names_b2 = ['bbeam_b2','arc']
'''
elements_b1 = [bbeam_b1,arc, IP2_bbeam_b1]
elements_b2 = [bbeam_b2,arc, IP2_bbeam_b2]

line_b1 = xt.Line(elements=elements_b1)
line_b2 = xt.Line(elements=elements_b2)
line_b1.build_tracker()
line_b2.build_tracker()
branch_b1 = xt.PipelineBranch(line_b1,particles_b1)
branch_b2 = xt.PipelineBranch(line_b2,particles_b2)


multitracker = xt.PipelineMultiTracker(branches=[branch_b1,branch_b2])


record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D, 
                                                        capacity={
                                                            "beamstrahlungtable": int(0),
                                                            "bhabhatable": int(0),
                                                            "lumitable": nTurn,
                                                            "numlumitable": nTurn
                                                        })


print('Tracking...')
time0 = time.time()

multitracker.track(num_turns=nTurn,turn_by_turn_monitor=True)
print('Done with tracking.',(time.time()-time0)/10,'[s/turn]')
line_b1.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)

record_qss_b1.move(_context=xo.context_default)


lumi_b1_beambeam = record_qss_b1.lumitable.luminosity
num_lumi_b1_beambeam = bbeam_b1.numlumitable.numerical_luminosity
grid = bbeam_b1.lumigrid_sum
print('Gaussian Luminosity with beam-beam:',frev*lumi_b1_beambeam)
print('Numerical Integrator Luminosity with beam-beam:',num_lumi_b1_beambeam)
print(np.sum(grid))
def Lumi_analytical(Nb, N1, N2, frev, Delta_i, sig_i, sig_x, sig_y):
    W = np.exp(-Delta_i**2/(4*sig_i**2))
    return ((Nb * N1 * N2 * frev * W)/(4 * np.pi * sig_x * sig_y))

print('analytical:',Lumi_analytical(1, bunch_intensity, bunch_intensity, frev, 0,np.sqrt(physemit_x*beta_x), np.sqrt(physemit_x*beta_x), np.sqrt(physemit_y*beta_x)))
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 100000
# Tracking...
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.446620798110962 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [1.73757945e+34 1.74001549e+34 1.73828152e+34]
# 8.855000692435162e+19
# analytical: 8.210370466096245e+34

# %%
p0c = 45.6e9
bunch_intensity = 1.7E11
physemit_x = 0.27e-9
physemit_y = 1e-12
beta_x = 0.15
beta_y = 0.8e-3
sigma_z = 3.5e-3
sigma_delta = 8.4E-4
beta_s = sigma_z/sigma_delta
Qx = 269.13
Qy = 267.18
Qs = 0.0025
frev = 3070 
nTurn = 3


# Define parameter ranges for scans
n_macroparticles_list = [100, 500, 1000, 5000, 100000, 500000, 1000000, 5000000]
n_lumigrid_cells_list = [10, 20, 50, 100, 200, 500, 1000, 2500] 
lumi_macroparticles = []

for n_macroparticles in n_macroparticles_list: 
    xs_b1 = []
    ys_b1 = []
    xs_b2 = []
    ys_b2 = []
    pxs_b1 = []
    pys_b1 = []
    pxs_b2 = []
    pys_b2 = []

    pipeline_manager = xt.PipelineManager()
    pipeline_manager.add_particles('b1',0)
    pipeline_manager.add_particles('b2',0)
    pipeline_manager.add_element('IP1')
    pipeline_manager.add_element('IP2')

    particles_b1 = xp.Particles(_context=context,
    p0c=p0c,
    x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
    px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
    y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
    py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
    zeta=sigma_z*np.random.randn(n_macroparticles),
    delta=sigma_delta*np.random.randn(n_macroparticles),
    weight=bunch_intensity/n_macroparticles
    )
    particles_b1.init_pipeline('b1')
    particles_b2 = xp.Particles(_context=context,
        p0c=p0c,
        x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
        px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
        y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
        py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
        zeta=sigma_z*np.random.randn(n_macroparticles),
        delta=sigma_delta*np.random.randn(n_macroparticles),
        weight=bunch_intensity/n_macroparticles
    )
    particles_b2.init_pipeline('b2')

    #############
    # Beam-beam #
    #############
    slicer = xf.TempSlicer(sigma_z=sigma_z, n_slices=1, mode = 'shatilov')
    config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
    pipeline_manager=pipeline_manager,
    element_name='IP1',
    partner_particles_name = 'b2',
    slicer=slicer,
    update_every=1,
    )
    config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
    pipeline_manager=pipeline_manager,
    element_name='IP1',
    partner_particles_name = 'b1',
    slicer=slicer,
    update_every=1,
    )
    
    IP2_config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
    pipeline_manager=pipeline_manager,
    element_name='IP2',
    partner_particles_name = 'b2',
    slicer=slicer,
    update_every=1,
    )
    IP2_config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
    pipeline_manager=pipeline_manager,
    element_name='IP2',
    partner_particles_name = 'b1',
    slicer=slicer,
    update_every=1,
    )
    
    print('build bb elements...')

    bbeam_b1 = xf.BeamBeamBiGaussian3D(
                _context=context,
                other_beam_q0 = particles_b2.q0,
                phi = 0,alpha=0,
                config_for_update = config_for_update_b1,
                flag_numerical_luminosity = 1,
                flag_luminosity = 1,
                n_lumigrid_cells=1500,
                sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
                range_lumigrid_cells = 24,
                n_macroparticles=n_macroparticles,
                nTurn = nTurn,
                update_lumigrid_sum=1
                )
    bbeam_b2 = xf.BeamBeamBiGaussian3D(
                _context=context,
                other_beam_q0 = particles_b1.q0,
                phi = 0,alpha=0,
                config_for_update = config_for_update_b2,
                flag_numerical_luminosity = 1,
                flag_luminosity = 1,
                n_lumigrid_cells=1500,
                sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
                range_lumigrid_cells = 24,
                n_macroparticles=n_macroparticles,
                nTurn = nTurn,
                update_lumigrid_sum=1
                )
    print(n_macroparticles)

    IP2_bbeam_b1 = xf.BeamBeamBiGaussian3D(
                _context=context,
                other_beam_q0 = particles_b2.q0,
                phi = 0,alpha=0,
                config_for_update = IP2_config_for_update_b1,
                flag_numerical_luminosity = 0,
                flag_luminosity = 1,
                update_lumigrid_sum=1)
    IP2_bbeam_b2 = xf.BeamBeamBiGaussian3D(
                _context=context,
                other_beam_q0 = particles_b1.q0,
                phi = 0,alpha=0,
                config_for_update = IP2_config_for_update_b2,
                flag_numerical_luminosity= 0,
                flag_luminosity = 1,
                update_lumigrid_sum=1)




    #################################################################
    # arcs (here they are all the same with half the phase advance) #
    #################################################################
    
    arc = xt.LineSegmentMap(
            betx = beta_x,bety = beta_y,
            qx = Qx/2, qy = Qy/2,bets = beta_s, qs=Qs)
    #################################################################
    # Tracker                                                       #
    #################################################################

    '''
    elements_b1 = [bbeam_b1,arc]
    elements_b2 = [bbeam_b2,arc]
    element_names_b1 = ['bbeam_b1','arc']
    element_names_b2 = ['bbeam_b2','arc']
    '''
    elements_b1 = [bbeam_b1,arc, IP2_bbeam_b1]
    elements_b2 = [bbeam_b2,arc, IP2_bbeam_b2]
    
    line_b1 = xt.Line(elements=elements_b1)
    line_b2 = xt.Line(elements=elements_b2)
    line_b1.build_tracker()
    line_b2.build_tracker()
    branch_b1 = xt.PipelineBranch(line_b1,particles_b1)
    branch_b2 = xt.PipelineBranch(line_b2,particles_b2)


    multitracker = xt.PipelineMultiTracker(branches=[branch_b1,branch_b2])

    record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D, 
                                                        capacity={
                                                            "beamstrahlungtable": int(0),
                                                            "bhabhatable": int(0),
                                                            "lumitable": nTurn,
                                                            "numlumitable": nTurn
                                                        })


    print('Tracking...')
    time0 = time.time()
    
    multitracker.track(num_turns=nTurn,turn_by_turn_monitor=True)
    print('Done with tracking.',(time.time()-time0)/10,'[s/turn]')
    line_b1.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)
    
    record_qss_b1.move(_context=xo.context_default)

    lumi_b1_beambeam = record_qss_b1.lumitable.luminosity
    num_lumi_b1_beambeam = bbeam_b1.numlumitable.numerical_luminosity
    grid = bbeam_b1.lumigrid_sum
    print('Gaussian Luminosity with beam-beam:',frev*lumi_b1_beambeam)
    print('Numerical Integrator Luminosity with beam-beam:',num_lumi_b1_beambeam)
    lumi_macroparticles.append(num_lumi_b1_beambeam[0])
    print(np.sum(grid))
    def Lumi_analytical(Nb, N1, N2, frev, Delta_i, sig_i, sig_x, sig_y):
        W = np.exp(-Delta_i**2/(4*sig_i**2))
        return ((Nb * N1 * N2 * frev * W)/(4 * np.pi * sig_x * sig_y))
    
    print('analytical:',Lumi_analytical(1, bunch_intensity, bunch_intensity, frev, 0,np.sqrt(physemit_x*beta_x), np.sqrt(physemit_x*beta_x), np.sqrt(physemit_y*beta_x)))
lumi_macroparticles = np.array(lumi_macroparticles)
print(lumi_macroparticles)
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 100
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.40903959274292 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [2.56961042e+37 1.42229732e+38 3.30996388e+37]
# 1.486783682409505e+20
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 500
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.393777585029602 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [2.34042196e+37 2.64798555e+37 4.13069838e+37]
# 7.521985022536905e+20
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 1000
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.40416898727417 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [3.32369172e+37 2.49053275e+37 2.65015432e+37]
# 1.5609136079867908e+21
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 5000
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.4562660217285157 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [2.97691927e+37 3.03714378e+37 2.93968064e+37]
# 7.865762126474229e+21
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 100000
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.4263468980789185 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [3.05722445e+37 3.05706947e+37 3.04639288e+37]
# 1.546834440707017e+23
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 500000
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.6361977100372314 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [3.04000330e+37 3.03825649e+37 3.03634019e+37]
# 7.729953553632243e+23
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 1000000
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 2.743209218978882 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [3.04592767e+37 3.04449077e+37 3.04367215e+37]
# 1.5479948607295096e+24
# analytical: 2.864528932364944e+36
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 5000000
# Tracking...
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# lumigrid_my_beam size: (1500, 1500)
# exchange_buffer size: (2250017,)
# Done with tracking. 4.070554494857788 [s/turn]
# Gaussian Luminosity with beam-beam: [0. 0. 0.]
# Numerical Integrator Luminosity with beam-beam: [3.04483770e+37 3.04561047e+37 3.04559265e+37]
# 7.74185721309678e+24
# analytical: 2.864528932364944e+36
# [2.56961042e+37 2.34042196e+37 3.32369172e+37 2.97691927e+37
#  3.05722445e+37 3.04000330e+37 3.04592767e+37 3.04483770e+37]

# %%
n_lumigrid_cells_list = [10, 20, 50, 100, 200, 500, 1000, 2500] 
#n_macroparticles = 1000
lumi_lumigrid_cells = []
lumi_results = []
for n_macroparticles in n_macroparticles_list:    
    for n_lumigrid_cells in n_lumigrid_cells_list: 
        xs_b1 = []
        ys_b1 = []
        xs_b2 = []
        ys_b2 = []
        pxs_b1 = []
        pys_b1 = []
        pxs_b2 = []
        pys_b2 = []
        print(f"Running with n_macroparticles={n_macroparticles}, n_lumigrid_cells={n_lumigrid_cells}")
        pipeline_manager = xt.PipelineManager()
        pipeline_manager.add_particles('b1',0)
        pipeline_manager.add_particles('b2',0)
        pipeline_manager.add_element('IP1')
        pipeline_manager.add_element('IP2')
    
        particles_b1 = xp.Particles(_context=context,
        p0c=p0c,
        x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
        px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
        y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
        py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
        zeta=sigma_z*np.random.randn(n_macroparticles),
        delta=sigma_delta*np.random.randn(n_macroparticles),
        weight=bunch_intensity/n_macroparticles
        )
        particles_b1.init_pipeline('b1')
        particles_b2 = xp.Particles(_context=context,
            p0c=p0c,
            x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
            px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
            y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
            py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
            zeta=sigma_z*np.random.randn(n_macroparticles),
            delta=sigma_delta*np.random.randn(n_macroparticles),
            weight=bunch_intensity/n_macroparticles
        )
        particles_b2.init_pipeline('b2')
    
        #############
        # Beam-beam #
        #############
        slicer = xf.TempSlicer(sigma_z=sigma_z, n_slices=1, mode = 'shatilov')
        config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP1',
        partner_particles_name = 'b2',
        slicer=slicer,
        update_every=1,
        )
        config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP1',
        partner_particles_name = 'b1',
        slicer=slicer,
        update_every=1,
        )
        
        IP2_config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP2',
        partner_particles_name = 'b2',
        slicer=slicer,
        update_every=1,
        )
        IP2_config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP2',
        partner_particles_name = 'b1',
        slicer=slicer,
        update_every=1,
        )
        
        print('build bb elements...')
    
        bbeam_b1 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b2.q0,
                    phi = 0,alpha=0,
                    config_for_update = config_for_update_b1,
                    flag_numerical_luminosity = 1,
                    flag_luminosity = 1,
                    n_lumigrid_cells=n_lumigrid_cells,
                    sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
                    range_lumigrid_cells = 24,
                    n_macroparticles=n_macroparticles,
                    nTurn = nTurn,
                    update_lumigrid_sum=1
                    )
        bbeam_b2 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b1.q0,
                    phi = 0,alpha=0,
                    config_for_update = config_for_update_b2,
                    flag_numerical_luminosity = 1,
                    flag_luminosity = 1,
                    n_lumigrid_cells=n_lumigrid_cells,
                    sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
                    range_lumigrid_cells = 24,
                    n_macroparticles=n_macroparticles,
                    nTurn = nTurn,
                    update_lumigrid_sum=1
                    )
        print(n_macroparticles)
    
        IP2_bbeam_b1 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b2.q0,
                    phi = 0,alpha=0,
                    config_for_update = IP2_config_for_update_b1,
                    flag_numerical_luminosity = 0,
                    flag_luminosity = 1,
                    update_lumigrid_sum=1)
        IP2_bbeam_b2 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b1.q0,
                    phi = 0,alpha=0,
                    config_for_update = IP2_config_for_update_b2,
                    flag_numerical_luminosity= 0,
                    flag_luminosity = 1,
                    update_lumigrid_sum=1)
    
    
    
    
        #################################################################
        # arcs (here they are all the same with half the phase advance) #
        #################################################################
        
        arc = xt.LineSegmentMap(
                betx = beta_x,bety = beta_y,
                qx = Qx/2, qy = Qy/2,bets = beta_s, qs=Qs)
        #################################################################
        # Tracker                                                       #
        #################################################################
    
        '''
        elements_b1 = [bbeam_b1,arc]
        elements_b2 = [bbeam_b2,arc]
        element_names_b1 = ['bbeam_b1','arc']
        element_names_b2 = ['bbeam_b2','arc']
        '''
        elements_b1 = [bbeam_b1,arc, IP2_bbeam_b1]
        elements_b2 = [bbeam_b2,arc, IP2_bbeam_b2]
        
        line_b1 = xt.Line(elements=elements_b1)
        line_b2 = xt.Line(elements=elements_b2)
        line_b1.build_tracker()
        line_b2.build_tracker()
        branch_b1 = xt.PipelineBranch(line_b1,particles_b1)
        branch_b2 = xt.PipelineBranch(line_b2,particles_b2)
    
    
        multitracker = xt.PipelineMultiTracker(branches=[branch_b1,branch_b2])
    
        record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D, 
                                                            capacity={
                                                                "beamstrahlungtable": int(0),
                                                                "bhabhatable": int(0),
                                                                "lumitable": nTurn,
                                                                "numlumitable": nTurn
                                                            })
    
    
       # Start internal logging BEFORE tracking
        record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(
        xf.BeamBeamBiGaussian3D, capacity={"lumitable": nTurn, "numlumitable": nTurn}
    )

        # Start tracking
        print("Tracking...")
        time0 = time.time()
        multitracker.track(num_turns=nTurn, turn_by_turn_monitor=True)
        print('Done with tracking.', (time.time() - time0) / nTurn, '[s/turn]')

    # Stop logging
    line_b1.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)

    # Move data to CPU context
    record_qss_b1.move(_context=xo.context_default)


        # Store results
        lumi_results.append([n_macroparticles, n_lumigrid_cells, num_lumi_b1_beambeam[0]])

# Convert to numpy array
lumi_results = np.array(lumi_results)
record_qss_b1.move(_context=xo.context_default)
    
lumi_b1_beambeam = record_qss_b1.lumitable.luminosity
num_lumi_b1_beambeam = bbeam_b1.numlumitable.numerical_luminosity
grid = bbeam_b1.lumigrid_sum
lumi_macroparticles = []
print('Gaussian Luminosity with beam-beam:',frev*lumi_b1_beambeam)
print('Numerical Integrator Luminosity with beam-beam:',num_lumi_b1_beambeam)
lumi_lumigrid_cells.append(num_lumi_b1_beambeam[0])
print(np.sum(grid))
def Lumi_analytical(Nb, N1, N2, frev, Delta_i, sig_i, sig_x, sig_y):
    W = np.exp(-Delta_i**2/(4*sig_i**2))
    return ((Nb * N1 * N2 * frev * W)/(4 * np.pi * sig_x * sig_y))
        
print('analytical:',Lumi_analytical(1, bunch_intensity, bunch_intensity, frev, 0,np.sqrt(physemit_x*beta_x), np.sqrt(physemit_x*beta_x), np.sqrt(physemit_y*beta_x)))
lumi_lumigrid_cells = np.array(lumi_lumigrid_cells)
print(lumi_lumigrid_cells)
# # Combine results into a 2D histogram data
# x_vals = np.concatenate((lumi_macroparticles[:, 0], lumi_lumigrid_cells[:, 0]))
# y_vals = np.concatenate((lumi_macroparticles[:, 1], lumi_lumigrid_cells[:, 1]))
        
# # Plot 2D histogram
# plt.figure(figsize=(8, 6))
# plt.hist2d(x_vals, y_vals, bins=(len(n_macroparticles_list), len(n_lumigrid_cells_list)), cmap='plasma')
# plt.colorbar(label='Luminosity')
# plt.xlabel('n_macroparticles / n_lumigrid_cells')
# plt.ylabel('Luminosity')
# plt.title('2D Histogram of Luminosity vs. Parameters')
# plt.show()
# Out:
# Running with n_macroparticles=100, n_lumigrid_cells=10
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 100
# Tracking...
# lumigrid_my_beam size: (10, 10)
# exchange_buffer size: (117,)
# lumigrid_my_beam size: (10, 10)
# exchange_buffer size: (117,)
# lumigrid_my_beam size: (10, 10)
# exchange_buffer size: (117,)
# lumigrid_my_beam size: (10, 10)
# exchange_buffer size: (117,)
# lumigrid_my_beam size: (10, 10)
# exchange_buffer size: (117,)
# lumigrid_my_beam size: (10, 10)
# exchange_buffer size: (117,)
# Done with tracking. 0.01015798250834147 [s/turn]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 177
#     174 print('Done with tracking.', (time.time() - time0) / nTurn, '[s/turn]')
#     176 # Retrieve luminosity
# --> 177 record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(
#     178     xf.BeamBeamBiGaussian3D, capacity={"lumitable": nTurn, "numlumitable": nTurn})
#     179 num_lumi_b1_beambeam = bbeam_b1.numlumitable.numerical_luminosity
#     181 # Store results
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/line.py:3185, in Line.start_internal_logging_for_elements_of_type(self, element_type, capacity)
#    3168 """
#    3169 Start internal logging for all elements of a given type.
#    3170
#    (...)
#    3182
#    3183 """
#    3184 self._check_valid_tracker()
# -> 3185 return start_internal_logging_for_elements_of_type(self.tracker,
#    3186                                             element_type, capacity)
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/internal_record.py:176, in start_internal_logging_for_elements_of_type(tracker, element_type, capacity)
#     174 def start_internal_logging_for_elements_of_type(tracker, element_type, capacity):
# --> 176     record = init_internal_record(element_type._internal_record_class, capacity,
#     177                                   tracker.io_buffer)
#     179     for nn in tracker.line.element_names:
#     180         ee = tracker.line.element_dict[nn]
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/internal_record.py:124, in init_internal_record(internal_record_class, capacity, io_buffer)
#     121                 if hasattr(sff.ftype, 'to_nplike'): #is array
#     122                     init_dict[ff.name][sff.name] = capacity[ff.name]
# --> 124 record = internal_record_class(_buffer=io_buffer, **init_dict)
#     126 if np.isscalar(capacity):
#     127     # One-level record
#     128     record._index.capacity = capacity
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/hybrid_class.py:283, in HybridClass.__init__(self, _xobject, **kwargs)
#     282 def __init__(self, _xobject=None, **kwargs):
# --> 283     self.xoinitialize(_xobject=_xobject, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/hybrid_class.py:272, in HybridClass.xoinitialize(self, _xobject, _kwargs_name_check, **kwargs)
#     269     else:
#     270         xo_kwargs[self._inverse_rename.get(kk, kk)] = vv
# --> 272 self._xobject = self._XoStruct(**xo_kwargs)
#     274 # Handle dressed inputs
#     275 for kk, vv in dressed_kwargs.items():
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:350, in Struct.__init__(self, _context, _buffer, _offset, *args, **kwargs)
#     348 args, kwargs = cls._pre_init(*args, **kwargs)
#     349 # compute resources
# --> 350 info = cls._inspect_args(*args, **kwargs)
#     351 self._size = info.size
#     352 # acquire buffer
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:243, in MetaStruct.__new__.<locals>._inspect_args(cls, *args, **kwargs)
#     241         raise ValueError(f"{arg} Not valid type for {cls}")
#     242 else:  # python argument
# --> 243     return cls._inspect_args(kwargs)
#     244 return info
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:222, in MetaStruct.__new__.<locals>._inspect_args(cls, *args, **kwargs)
#     220 # log.debug(f"{arg}")
#     221 for field in cls._d_fields:
# --> 222     farg = field.value_from_args(arg)
#     223     # log.debug(
#     224     #    f"get size for field `{field.name}` using `{farg}`"
#     225     # )
#     226     finfo = dispatch_arg(
#     227         field.ftype._inspect_args, farg
#     228     )
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:138, in Field.value_from_args(self, arg)
#     136     return arg[self.name]
#     137 else:
# --> 138     return self.get_default()
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:128, in Field.get_default(self)
#     126 if self.default_factory is None:
#     127     if self.default is None:
# --> 128         return self.ftype()
#     129     else:
#     130         return dispatch_arg(self.ftype, self.default)
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:350, in Struct.__init__(self, _context, _buffer, _offset, *args, **kwargs)
#     348 args, kwargs = cls._pre_init(*args, **kwargs)
#     349 # compute resources
# --> 350 info = cls._inspect_args(*args, **kwargs)
#     351 self._size = info.size
#     352 # acquire buffer
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:243, in MetaStruct.__new__.<locals>._inspect_args(cls, *args, **kwargs)
#     241         raise ValueError(f"{arg} Not valid type for {cls}")
#     242 else:  # python argument
# --> 243     return cls._inspect_args(kwargs)
#     244 return info
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:222, in MetaStruct.__new__.<locals>._inspect_args(cls, *args, **kwargs)
#     220 # log.debug(f"{arg}")
#     221 for field in cls._d_fields:
# --> 222     farg = field.value_from_args(arg)
#     223     # log.debug(
#     224     #    f"get size for field `{field.name}` using `{farg}`"
#     225     # )
#     226     finfo = dispatch_arg(
#     227         field.ftype._inspect_args, farg
#     228     )
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:138, in Field.value_from_args(self, arg)
#     136     return arg[self.name]
#     137 else:
# --> 138     return self.get_default()
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:128, in Field.get_default(self)
#     126 if self.default_factory is None:
#     127     if self.default is None:
# --> 128         return self.ftype()
#     129     else:
#     130         return dispatch_arg(self.ftype, self.default)
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/array.py:528, in Array.__init__(self, _context, _buffer, _offset, *args)
#     525 def __init__(self, *args, _context=None, _buffer=None, _offset=None):
#     526     # determin resources
#     527     cls = self.__class__
# --> 528     info = cls._inspect_args(*args)
#     530     self._buffer, self._offset = allocate_on_buffer(
#     531         info.size, _context, _buffer, _offset
#     532     )
#     534     cls._to_buffer(self._buffer, self._offset, info.value, info)
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/array.py:341, in Array._inspect_args(cls, *args)
#     339 else:  # complete dimensions
#     340     if len(args) == 0:
# --> 341         raise ValueError(
#     342             "Cannot initialize array with dynamic shape without arguments"
#     343         )
#     344     if not is_integer(args[0]):  # init with array
#     345         value = args[0]
#
# ValueError: Cannot initialize array with dynamic shape without arguments

# %%
print(lumi_lumigrid_cells)
print(lumi_macroparticles)
# Out:
# [1.23006195e+37 2.24819466e+37 3.02379827e+37 3.14321961e+37
#  3.11020286e+37 3.05713074e+37 3.25660253e+37 2.84504960e+37]
# []

# %%
# Combine results into a 2D histogram data
# x_vals = np.concatenate((lumi_macroparticles[:, 0], lumi_lumigrid_cells[:, 0]))
# y_vals = np.concatenate((lumi_macroparticles[:, 1], lumi_lumigrid_cells[:, 1]))

plt.plot(lumi_macroparticles, label="Macroparticle Scan")
plt.plot(lumi_lumigrid_cells, label="Lumigrid Cells Scan")

plt.xlabel("Runs")
plt.ylabel("Luminosity")
plt.title("Convergence Plot")
plt.legend()
plt.show()

# # Plot 2D histogram
# plt.figure(figsize=(8, 6))
# plt.hist2d(x_vals, y_vals, bins=(len(n_macroparticles_list), len(n_lumigrid_cells_list)), cmap='plasma')
# plt.colorbar(label='Luminosity')
# plt.xlabel('n_macroparticles / n_lumigrid_cells')
# plt.ylabel('Luminosity')
# plt.title('2D Histogram of Luminosity vs. Parameters')
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import xobjects as xo
import xtrack as xt
import xfieldsdevlumi as xf
import xpart as xp
import time

# ==========================
# Beam and Machine Parameters
# ==========================
context = xo.ContextCpu()

p0c = 45.6e9  # Beam energy [eV]
bunch_intensity = 1.7E11  # Particles per bunch
physemit_x = 0.27e-9  # Horizontal emittance [m]
physemit_y = 1e-12  # Vertical emittance [m]
beta_x = 0.15  # Beta function at IP (x)
beta_y = 0.8e-3  # Beta function at IP (y)
sigma_z = 3.5e-3  # Bunch length [m]
sigma_delta = 8.4E-4  # Momentum spread
beta_s = sigma_z / sigma_delta  # Synchrotron beta function
Qx = 269.13  # Horizontal tune
Qy = 267.18  # Vertical tune
Qs = 0.0025  # Synchrotron tune
frev = 3070  # Revolution frequency [Hz]
nTurn = 3  # Number of turns per run

# ==========================
# Parameter Ranges for Scan
# ==========================
n_macroparticles_list = [100, 500, 1000, 5000, 100000, 500000, 1000000]  
n_lumigrid_cells_list = [10, 20, 50, 100, 200, 500, 1000, 2500]

# Storage for results
lumi_results = []

# ==========================
# Start 2D Parameter Scan
# ==========================
for n_macroparticles in n_macroparticles_list:
    for n_lumigrid_cells in n_lumigrid_cells_list:
        print(f"Running with n_macroparticles={n_macroparticles}, n_lumigrid_cells={n_lumigrid_cells}")

        # Initialize pipeline manager
        pipeline_manager = xt.PipelineManager()
        pipeline_manager.add_particles('b1', 0)
        pipeline_manager.add_particles('b2', 0)
        pipeline_manager.add_element('IP1')
        pipeline_manager.add_element('IP2')

        # Generate particles
        particles_b1 = xp.Particles(
            _context=context,
            p0c=p0c,
            x=np.sqrt(physemit_x * beta_x) * np.random.randn(n_macroparticles),
            px=np.sqrt(physemit_x / beta_x) * np.random.randn(n_macroparticles),
            y=np.sqrt(physemit_y * beta_y) * np.random.randn(n_macroparticles),
            py=np.sqrt(physemit_y / beta_y) * np.random.randn(n_macroparticles),
            zeta=sigma_z * np.random.randn(n_macroparticles),
            delta=sigma_delta * np.random.randn(n_macroparticles),
            weight=bunch_intensity / n_macroparticles
        )
        particles_b1.init_pipeline('b1')
        particles_b2 = particles_b1.copy()
        particles_b2.init_pipeline('b2')

        # Beam-beam elements setup
        slicer = xf.TempSlicer(sigma_z=sigma_z, n_slices=1, mode='shatilov')
        config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
            pipeline_manager=pipeline_manager, element_name='IP1', partner_particles_name='b2', slicer=slicer, update_every=1)
        config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
            pipeline_manager=pipeline_manager, element_name='IP1', partner_particles_name='b1', slicer=slicer, update_every=1)

        # Beam-beam interaction elements
        bbeam_b1 = xf.BeamBeamBiGaussian3D(
            _context=context, other_beam_q0=particles_b2.q0, phi=0, alpha=0, config_for_update=config_for_update_b1,
            flag_numerical_luminosity=1, flag_luminosity=1, n_lumigrid_cells=n_lumigrid_cells,
            sig_lumigrid_cells=np.sqrt(physemit_x * beta_x), range_lumigrid_cells=24,
            n_macroparticles=n_macroparticles, nTurn=nTurn, update_lumigrid_sum=1)

        bbeam_b2 = bbeam_b1.copy()

        # Beam optics (arc segment)
        arc = xt.LineSegmentMap(betx=beta_x, bety=beta_y, qx=Qx / 2, qy=Qy / 2, bets=beta_s, qs=Qs)

        # Ensure BeamBeam element is registered
        #xt.tracker._element_classes_from_track_kernel(['BeamBeamBiGaussian3D'])
        
        # Move elements to context
        for element in line_b1.elements + line_b2.elements:
            element.move(_context=context)
        

        
        # Create tracking lines
        line_b1 = xt.Line(elements=[bbeam_b1, arc])
        line_b2 = xt.Line(elements=[bbeam_b2, arc])
        line_b1.build_tracker()
        #line_b2.build_tracker(use_prebuilt_kernels=True)

        # Pipeline branches
        branch_b1 = xt.PipelineBranch(line_b1, particles_b1)
        branch_b2 = xt.PipelineBranch(line_b2, particles_b2)
        multitracker = xt.PipelineMultiTracker(branches=[branch_b1, branch_b2])

        # Start tracking
        print("Tracking...")
        time0 = time.time()
        multitracker.track(num_turns=nTurn, turn_by_turn_monitor=True)
        print('Done with tracking.', (time.time() - time0) / nTurn, '[s/turn]')

        # Retrieve luminosity
        record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(
            xf.BeamBeamBiGaussian3D, capacity={"lumitable": nTurn, "numlumitable": nTurn})
        num_lumi_b1_beambeam = bbeam_b1.numlumitable.numerical_luminosity

        # Store results
        lumi_results.append([n_macroparticles, n_lumigrid_cells, num_lumi_b1_beambeam[0]])

# Convert to numpy array
lumi_results = np.array(lumi_results)

# ==========================
# 2D Histogram Visualization
# ==========================
plt.figure(figsize=(8, 6))
plt.hist2d(lumi_results[:, 0], lumi_results[:, 1], weights=lumi_results[:, 2], bins=(len(n_macroparticles_list), len(n_lumigrid_cells_list)), cmap='plasma')
plt.colorbar(label="Numerical Luminosity")
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")  # Log scale for better visualization
plt.yscale("log")  # Log scale for better visualization
plt.title("2D Histogram of Luminosity vs Macroparticles & Lumi Grid Cells")
plt.show()
# Out:
# Running with n_macroparticles=100, n_lumigrid_cells=10
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 104
#     100 #line_b2.build_tracker(use_prebuilt_kernels=True)
#     101
#     102 # Pipeline branches
#     103 branch_b1 = xt.PipelineBranch(line_b1, particles_b1)
# --> 104 branch_b2 = xt.PipelineBranch(line_b2, particles_b2)
#     105 multitracker = xt.PipelineMultiTracker(branches=[branch_b1, branch_b2])
#     107 # Start tracking
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/pipeline/multitracker.py:24, in PipelineBranch.__init__(self, line, particles, tracker)
#      21 self.pipeline_status = None
#      23 if self.line.tracker is None:
# ---> 24     raise ValueError('Tracker not built for line')
#      26 self.line.tracker.enable_pipeline_hold = True
#
# ValueError: Tracker not built for line
