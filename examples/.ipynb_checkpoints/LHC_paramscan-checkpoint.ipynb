# %%
#Attempting to delete all hardcoding from beambeam3d.py and having variables as inputs instead
import numpy as np
from matplotlib import pyplot as plt
import xobjects as xo
import xtrack as xt
import xfieldsdevlumi as xf
import xpart as xp
import time
# Generating sequences
        
n_macroparticles_list = [100, 200, 300, 500, 800, 1000, 5000, 100000, 500000, 1000000, 5000000, 10000000]  
n_lumigrid_cells_list = [10, 20, 50, 100, 200, 300, 500, 800, 1000, 1500, 2500, 5000]
lumi_results = []     
        
for n_macroparticles in n_macroparticles_list:
    for n_lumigrid_cells in n_lumigrid_cells_list:
                
        context = xo.ContextCpu(omp_num_threads=8)
        
        p0c = 6500e9
        bunch_intensity = 0.7825E11
        physemit_x = (2.946E-6*xp.PROTON_MASS_EV)/p0c 
        physemit_y = (2.946E-6*xp.PROTON_MASS_EV)/p0c 
        beta_x = 19.17
        beta_y = 19.17
        sigma_z = 0.08
        sigma_delta = 1E-4
        beta_s = sigma_z/sigma_delta
        Qx = 64.31
        Qy = 59.32
        Qs = 2.1E-3
        frev = 11245 
        nTurn = 3
        
        #n_macroparticles = int(100000)
        xs_b1 = []
        ys_b1 = []
        xs_b2 = []
        ys_b2 = []
        pxs_b1 = []
        pys_b1 = []
        pxs_b2 = []
        pys_b2 = []
        
        pipeline_manager = xt.PipelineManager()
        pipeline_manager.add_particles('b1',0)
        pipeline_manager.add_particles('b2',0)
        pipeline_manager.add_element('IP1')
        pipeline_manager.add_element('IP2')
        
        particles_b1 = xp.Particles(_context=context,
            p0c=p0c,
            x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
            px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
            y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
            py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
            zeta=sigma_z*np.random.randn(n_macroparticles),
            delta=sigma_delta*np.random.randn(n_macroparticles),
            weight=bunch_intensity/n_macroparticles
        )
        particles_b1.init_pipeline('b1')
        particles_b2 = xp.Particles(_context=context,
            p0c=p0c,
            x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
            px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
            y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
            py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
            zeta=sigma_z*np.random.randn(n_macroparticles),
            delta=sigma_delta*np.random.randn(n_macroparticles),
            weight=bunch_intensity/n_macroparticles
        )
        particles_b2.init_pipeline('b2')
        
        #############
        # Beam-beam #
        #############
        slicer = xf.TempSlicer(sigma_z=sigma_z, n_slices=1, mode = 'shatilov')
        config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP1',
        partner_particles_name = 'b2',
        slicer=slicer,
        update_every=1,
        )
        config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP1',
        partner_particles_name = 'b1',
        slicer=slicer,
        update_every=1,
        )
        
        IP2_config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP2',
        partner_particles_name = 'b2',
        slicer=slicer,
        update_every=1,
        )
        IP2_config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
        pipeline_manager=pipeline_manager,
        element_name='IP2',
        partner_particles_name = 'b1',
        slicer=slicer,
        update_every=1,
        )
        
        print('build bb elements...')
        bbeam_b1 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b2.q0,
                    phi = 0,alpha=0,
                    config_for_update = config_for_update_b1,
                    flag_numerical_luminosity = 1,
                    flag_luminosity = 1,
                    n_lumigrid_cells=n_lumigrid_cells,
                    sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
                    range_lumigrid_cells = 24,
                    n_macroparticles=n_macroparticles,
                    nTurn = nTurn,
                    update_lumigrid_sum=1
                    )
        bbeam_b2 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b1.q0,
                    phi = 0,alpha=0,
                    config_for_update = config_for_update_b2,
                    flag_numerical_luminosity = 1,
                    flag_luminosity = 1,
                    n_lumigrid_cells=n_lumigrid_cells,
                    sig_lumigrid_cells=np.sqrt(physemit_x*beta_x),
                    range_lumigrid_cells = 24,
                    n_macroparticles=n_macroparticles,
                    nTurn = nTurn,
                    update_lumigrid_sum=1
                    )
        print(n_macroparticles)
        IP2_bbeam_b1 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b2.q0,
                    phi = 0,alpha=0,
                    config_for_update = IP2_config_for_update_b1,
                    flag_numerical_luminosity = 0,
                    flag_luminosity = 1,
                    update_lumigrid_sum=1)
        IP2_bbeam_b2 = xf.BeamBeamBiGaussian3D(
                    _context=context,
                    other_beam_q0 = particles_b1.q0,
                    phi = 0,alpha=0,
                    config_for_update = IP2_config_for_update_b2,
                    flag_numerical_luminosity= 0,
                    flag_luminosity = 1,
                    update_lumigrid_sum=1)
        
        
        #################################################################
        # arcs (here they are all the same with half the phase advance) #
        #################################################################
        
        arc = xt.LineSegmentMap(
                betx = beta_x,bety = beta_y,
                qx = Qx/2, qy = Qy/2,bets = beta_s, qs=Qs)
        #################################################################
        # Tracker                                                       #
        #################################################################
        '''
        elements_b1 = [bbeam_b1,arc]
        elements_b2 = [bbeam_b2,arc]
        element_names_b1 = ['bbeam_b1','arc']
        element_names_b2 = ['bbeam_b2','arc']
        '''
        elements_b1 = [bbeam_b1,arc, IP2_bbeam_b1]
        elements_b2 = [bbeam_b2,arc, IP2_bbeam_b2]
        
        line_b1 = xt.Line(elements=elements_b1)
        line_b2 = xt.Line(elements=elements_b2)
        line_b1.build_tracker()
        line_b2.build_tracker()
        branch_b1 = xt.PipelineBranch(line_b1,particles_b1)
        branch_b2 = xt.PipelineBranch(line_b2,particles_b2)
        
        
        multitracker = xt.PipelineMultiTracker(branches=[branch_b1,branch_b2])
        
        
        record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D, 
                                                                capacity={
                                                                    "beamstrahlungtable": int(0),
                                                                    "bhabhatable": int(0),
                                                                    "lumitable": nTurn,
                                                                    "numlumitable": nTurn
                                                                })
        
        
        print('Tracking...')
        time0 = time.time()
        
        multitracker.track(num_turns=nTurn,turn_by_turn_monitor=True)
        print('Done with tracking.',(time.time()-time0)/10,'[s/turn]')
        line_b1.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)
        
        record_qss_b1.move(_context=xo.context_default)
        
        
        lumi_b1_beambeam = record_qss_b1.lumitable.luminosity
        num_lumi_b1_beambeam = bbeam_b1.numlumitable.numerical_luminosity
        grid = bbeam_b1.lumigrid_sum
        lumi_results.append([n_macroparticles, n_lumigrid_cells, num_lumi_b1_beambeam[0]])
        print('Gaussian Luminosity with beam-beam:',frev*lumi_b1_beambeam)
        print('Numerical Integrator Luminosity with beam-beam:',num_lumi_b1_beambeam)
        print(np.sum(grid))
        def Lumi_analytical(Nb, N1, N2, frev, Delta_i, sig_i, sig_x, sig_y):
            W = np.exp(-Delta_i**2/(4*sig_i**2))
            return ((Nb * N1 * N2 * frev * W)/(4 * np.pi * sig_x * sig_y))
        
        print('analytical:',Lumi_analytical(1, bunch_intensity, bunch_intensity, frev, 0,np.sqrt(physemit_x*beta_x), np.sqrt(physemit_x*beta_x), np.sqrt(physemit_y*beta_x)))


analytical_lumi = Lumi_analytical(1, bunch_intensity, bunch_intensity, frev, 
                                  0, np.sqrt(physemit_x * beta_x), 
                                  np.sqrt(physemit_x * beta_x), 
                                  np.sqrt(physemit_y * beta_y))

# Extract values from the results table
lumi_results = np.array(lumi_results)
n_macroparticles = lumi_results[:, 0]
n_lumigrid_cells = lumi_results[:, 1]
luminosities = lumi_results[:, 2]

# Normalize luminosities
normalised_lumis = luminosities / analytical_lumi  # Ensures no 0s

# Define log-scaled bins
bins_x = np.logspace(np.log10(n_macroparticles.min()), np.log10(n_macroparticles.max()), 10)
bins_y = np.logspace(np.log10(n_lumigrid_cells.min()), np.log10(n_lumigrid_cells.max()), 10)

# Create the 2D histogram
plt.figure(figsize=(8, 6), facecolor='white')
#plt.gca().set_facecolor("white")

hist, xedges, yedges, img = plt.hist2d(
    n_macroparticles, 
    n_lumigrid_cells, 
    bins=[bins_x, bins_y], 
    weights=normalised_lumis,  # Use normalised values
    cmap="plasma", 
    norm=plt.Normalize(vmin=0.1, vmax=1.5)  # Adjusted scale for visibility
)

hist_masked = np.ma.masked_where(hist == 0, hist)
img.set_array(hist_masked.ravel())


# Add colorbar
cbar = plt.colorbar(img)
cbar.set_label("Normalized Numerical Luminosity (Analytical = 1.0)")

# Set axis labels and scaling
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")
plt.yscale("log")
plt.title("Fixed Normalized 2D Histogram of Luminosity")
plt.show()

# # Convert to Numpy Array for Plotting
# lumi_results = np.array(lumi_results)

# # ==========================
# # 2D Histogram Visualization
# # ==========================
# plt.figure(figsize=(8, 6))
# plt.hist2d(lumi_results[:, 0], lumi_results[:, 1], weights=lumi_results[:, 2], 
#            bins=(len(n_macroparticles_list), len(n_lumigrid_cells_list)), cmap='plasma')

# plt.colorbar(label="Numerical Luminosity")
# plt.xlabel("Number of Macroparticles")
# plt.ylabel("Number of Lumi Grid Cells")
# plt.xscale("log")  
# plt.yscale("log")  
# plt.title("2D Histogram of Luminosity vs Macroparticles & Lumi Grid Cells")
# plt.show()
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# build bb elements...
# 100
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Tracking...
# Compiling ContextCpu kernels...
# ld: warning: dylib (/Users/arizakhtar/miniforge3/lib/libomp.dylib) was built for newer macOS version (11.1) than being linked (11.0)
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 198
#     195 print('Tracking...')
#     196 time0 = time.time()
# --> 198 multitracker.track(num_turns=nTurn,turn_by_turn_monitor=True)
#     199 print('Done with tracking.',(time.time()-time0)/10,'[s/turn]')
#     200 line_b1.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/pipeline/multitracker.py:41, in PipelineMultiTracker.track(self, **kwargs)
#      38 def track(self, **kwargs):
#      40     for branch in self.branches:
# ---> 41         branch.pipeline_status = branch.line.track(
#      42              branch.particles, **kwargs,
#      43              _called_by_pipeline=True)
#      45     need_resume = True
#      46     while need_resume:
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/line.py:1059, in Line.track(self, particles, ele_start, ele_stop, num_elements, num_turns, turn_by_turn_monitor, freeze_longitudinal, time, with_progress, **kwargs)
#    1056 if not self._has_valid_tracker():
#    1057     self.build_tracker()
# -> 1059 return self.tracker._track(
#    1060     particles,
#    1061     ele_start=ele_start,
#    1062     ele_stop=ele_stop,
#    1063     num_elements=num_elements,
#    1064     num_turns=num_turns,
#    1065     turn_by_turn_monitor=turn_by_turn_monitor,
#    1066     freeze_longitudinal=freeze_longitudinal,
#    1067     time=time,
#    1068     with_progress=with_progress,
#    1069     **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/tracker.py:377, in Tracker._track(self, particles, with_progress, time, *args, **kwargs)
#     374         tracking_func(particles, *args, **one_turn_kwargs)
#     375         # particles.reorganize() # could be done in the future to optimize GPU usage
#     376 else:
# --> 377     out = tracking_func(particles, *args, **kwargs)
#     379 if time:
#     380     t1 = perf_counter()
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/tracker.py:1002, in Tracker._track_with_collective(self, particles, ele_start, ele_stop, num_elements, num_turns, turn_by_turn_monitor, freeze_longitudinal, backtrack, log, _session_to_resume, _reset_log)
#     999     monitor_part = None
#    1001 # Track!
# -> 1002 stop_tracking, skip, returned_by_track = self._track_part(
#    1003         particles, pp, tt, ipp, ele_start, ele_stop, num_turns, monitor_part)
#    1005 if returned_by_track is not None:
#    1006     if returned_by_track.on_hold:
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/tracker.py:842, in Tracker._track_part(self, particles, pp, tt, ipp, ele_start, ele_stop, num_turns, monitor)
#     839 i_start_in_part = self._element_index_in_part[ele_start]
#     840 if i_start_in_part is None:
#     841     # The start part is collective
# --> 842     ret = pp.track(particles)
#     843 else:
#     844     # The start part is a non-collective tracker
#     845     if (ele_stop is not None
#     846         and tt == num_turns - 1 and self._element_part[ele_stop] == ipp):
#     847         # The stop element is also in this part, so track until ele_stop
#
# File ~/Documents/Ariz/Physics_MSci/Year_3/Masters_Project/xfieldsdevlumi/xfieldsdevlumi/beam_elements/beambeam3d.py:806, in BeamBeamBiGaussian3D._track_collective(self, particles, _force_suspend)
#     803     self.config_for_update._do_update = False
#     805 # Change reference frame
# --> 806 self.change_ref_frame(particles)
#     808 # Can be used to test the resume without pipeline
#     809 if _force_suspend:
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/base_element.py:676, in PerParticlePyMethod.__call__(self, particles, increment_at_element, **kwargs)
#     673 context = instance._context
#     675 only_if_needed = kwargs.pop('only_if_needed', True)
# --> 676 BeamElement.compile_kernels(instance, only_if_needed=only_if_needed)
#     677 kernel = context.kernels[self.kernel_name]
#     679 if hasattr(self.element, 'io_buffer') and self.element.io_buffer is not None:
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/base_element.py:515, in BeamElement.compile_kernels(self, extra_classes, *args, **kwargs)
#     513         context.kernels.update(kernels)
#     514         return
# --> 515 xo.HybridClass.compile_kernels(
#     516     self,
#     517     extra_classes=[Particles._XoStruct],
#     518     *args,
#     519     **kwargs,
#     520 )
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/hybrid_class.py:381, in HybridClass.compile_kernels(self, *args, **kwargs)
#     380 def compile_kernels(self, *args, **kwargs):
# --> 381     return self._xobject.compile_kernels(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:501, in Struct.compile_kernels(self, only_if_needed, apply_to_source, save_source_as, extra_classes)
#     494 def compile_kernels(
#     495     self,
#     496     only_if_needed=False,
#    (...)
#     499     extra_classes=(),
#     500 ):
# --> 501     self.compile_class_kernels(
#     502         context=self._context,
#     503         only_if_needed=only_if_needed,
#     504         apply_to_source=apply_to_source,
#     505         save_source_as=save_source_as,
#     506         extra_classes=extra_classes,
#     507     )
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/struct.py:486, in Struct.compile_class_kernels(cls, context, only_if_needed, apply_to_source, save_source_as, extra_classes)
#     483     if all_found:
#     484         return
# --> 486 context.add_kernels(
#     487     sources=[],
#     488     kernels=cls._kernels,
#     489     extra_classes=[cls] + list(extra_classes),
#     490     apply_to_source=apply_to_source,
#     491     save_source_as=save_source_as,
#     492 )
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/context_cpu.py:250, in ContextCpu.add_kernels(self, sources, kernels, specialize, apply_to_source, save_source_as, extra_compile_args, extra_link_args, extra_cdef, extra_classes, extra_headers, compile)
#     247 kernels = kernels or {}
#     248 sources = sources or []
# --> 250 generated_kernels = self.build_kernels(
#     251     kernel_descriptions=kernels,
#     252     sources=sources,
#     253     specialize=specialize,
#     254     apply_to_source=apply_to_source,
#     255     save_source_as=save_source_as,
#     256     extra_compile_args=extra_compile_args,
#     257     extra_link_args=extra_link_args,
#     258     extra_cdef=extra_cdef,
#     259     extra_classes=extra_classes,
#     260     extra_headers=extra_headers,
#     261     compile=compile,
#     262 )
#     263 self.kernels.update(generated_kernels)
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/context_cpu.py:316, in ContextCpu.build_kernels(self, kernel_descriptions, module_name, containing_dir, sources, specialize, apply_to_source, save_source_as, extra_compile_args, extra_link_args, extra_cdef, extra_classes, extra_headers, compile)
#     313 if _forbid_compile:
#     314     raise RuntimeError("Compilation is forbidden")
# --> 316 so_file = self.compile_kernel(
#     317     module_name,
#     318     kernel_descriptions,
#     319     cdefs,
#     320     specialized_source,
#     321     extra_compile_args,
#     322     extra_link_args,
#     323     containing_dir=containing_dir,
#     324 )
#     326 try:
#     327     # Import the compiled module
#     328     out_kernels = self.kernels_from_file(
#     329         module_name,
#     330         kernel_descriptions,
#     331         containing_dir=containing_dir,
#     332     )
#
# File ~/miniforge3/lib/python3.12/site-packages/xobjects/context_cpu.py:447, in ContextCpu.compile_kernel(self, module_name, kernel_descriptions, cdefs, specialized_source, extra_compile_args, extra_link_args, containing_dir)
#     443 try:
#     444     so_file = str(
#     445         _so_for_module_name(module_name, containing_dir).absolute()
#     446     )
# --> 447     output_file = ffi_interface.compile(
#     448         target=so_file, verbose=self._cffi_verbose
#     449     )
#     450     if self._compile_kernels_info:
#     451         _print("Done compiling ContextCpu kernels.")
#
# File ~/miniforge3/lib/python3.12/site-packages/cffi/api.py:727, in FFI.compile(self, tmpdir, verbose, target, debug)
#     725     raise ValueError("set_source() must be called before compile()")
#     726 module_name, source, source_extension, kwds = self._assigned_source
# --> 727 return recompile(self, module_name, source, tmpdir=tmpdir,
#     728                  target=target, source_extension=source_extension,
#     729                  compiler_verbose=verbose, debug=debug, **kwds)
#
# File ~/miniforge3/lib/python3.12/site-packages/cffi/recompiler.py:1581, in recompile(ffi, module_name, preamble, tmpdir, call_c_compiler, c_file, source_extension, extradir, compiler_verbose, target, debug, uses_ffiplatform, **kwds)
#    1579         print('%s %r' % (msg, os.path.abspath(tmpdir)))
#    1580     os.chdir(tmpdir)
# -> 1581     outputfilename = ffiplatform.compile('.', ext,
#    1582                                          compiler_verbose, debug)
#    1583 finally:
#    1584     os.chdir(cwd)
#
# File ~/miniforge3/lib/python3.12/site-packages/cffi/ffiplatform.py:20, in compile(tmpdir, ext, compiler_verbose, debug)
#      18 saved_environ = os.environ.copy()
#      19 try:
# ---> 20     outputfilename = _build(tmpdir, ext, compiler_verbose, debug)
#      21     outputfilename = os.path.abspath(outputfilename)
#      22 finally:
#      23     # workaround for a distutils bugs where some env vars can
#      24     # become longer and longer every time it is used
#
# File ~/miniforge3/lib/python3.12/site-packages/cffi/ffiplatform.py:48, in _build(tmpdir, ext, compiler_verbose, debug)
#      46 try:
#      47     set_verbosity(compiler_verbose)
# ---> 48     dist.run_command('build_ext')
#      49     cmd_obj = dist.get_command_obj('build_ext')
#      50     [soname] = cmd_obj.get_outputs()
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/dist.py:999, in Distribution.run_command(self, command)
#     995 self.set_defaults()
#     996 # Postpone defaults until all explicit configuration is considered
#     997 # (setup() args, config files, command line and plugins)
# --> 999 super().run_command(command)
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/dist.py:1002, in Distribution.run_command(self, command)
#    1000 cmd_obj = self.get_command_obj(command)
#    1001 cmd_obj.ensure_finalized()
# -> 1002 cmd_obj.run()
#    1003 self.have_run[command] = True
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/command/build_ext.py:99, in build_ext.run(self)
#      97 """Build extensions in build directory, then copy if --inplace"""
#      98 old_inplace, self.inplace = self.inplace, False
# ---> 99 _build_ext.run(self)
#     100 self.inplace = old_inplace
#     101 if old_inplace:
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py:365, in build_ext.run(self)
#     362     self.compiler.set_link_objects(self.link_objects)
#     364 # Now actually compile and link everything.
# --> 365 self.build_extensions()
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py:481, in build_ext.build_extensions(self)
#     479     self._build_extensions_parallel()
#     480 else:
# --> 481     self._build_extensions_serial()
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py:507, in build_ext._build_extensions_serial(self)
#     505 for ext in self.extensions:
#     506     with self._filter_build_errors(ext):
# --> 507         self.build_extension(ext)
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/command/build_ext.py:264, in build_ext.build_extension(self, ext)
#     262 if isinstance(ext, Library):
#     263     self.compiler = self.shlib_compiler
# --> 264 _build_ext.build_extension(self, ext)
#     265 if ext._needs_stub:
#     266     build_lib = self.get_finalized_command('build_py').build_lib
#
# File ~/miniforge3/lib/python3.12/site-packages/Cython/Distutils/build_ext.py:135, in build_ext.build_extension(self, ext)
#     130 new_ext = cythonize(
#     131     ext,force=self.force, quiet=self.verbose == 0, **options
#     132 )[0]
#     134 ext.sources = new_ext.sources
# --> 135 super(build_ext, self).build_extension(ext)
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/command/build_ext.py:562, in build_ext.build_extension(self, ext)
#     559 for undef in ext.undef_macros:
#     560     macros.append((undef,))
# --> 562 objects = self.compiler.compile(
#     563     sources,
#     564     output_dir=self.build_temp,
#     565     macros=macros,
#     566     include_dirs=ext.include_dirs,
#     567     debug=self.debug,
#     568     extra_postargs=extra_args,
#     569     depends=ext.depends,
#     570 )
#     572 # XXX outdated variable, kept here in case third-part code
#     573 # needs it.
#     574 self._built_objects = objects[:]
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/ccompiler.py:607, in CCompiler.compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     605     except KeyError:
#     606         continue
# --> 607     self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     609 # Return *all* object filenames, not just the ones we just built.
#     610 return objects
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/unixccompiler.py:200, in UnixCCompiler._compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     196         self.spawn(
#     197             compiler_so_cxx + cc_args + [src, '-o', obj] + extra_postargs
#     198         )
#     199     else:
# --> 200         self.spawn(compiler_so + cc_args + [src, '-o', obj] + extra_postargs)
#     201 except DistutilsExecError as msg:
#     202     raise CompileError(msg)
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/ccompiler.py:1052, in CCompiler.spawn(self, cmd, **kwargs)
#    1051 def spawn(self, cmd, **kwargs):
# -> 1052     spawn(cmd, dry_run=self.dry_run, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/setuptools/_distutils/spawn.py:70, in spawn(cmd, search_path, verbose, dry_run, env)
#      67         cmd[0] = executable
#      69 try:
# ---> 70     subprocess.check_call(cmd, env=_inject_macos_ver(env))
#      71 except OSError as exc:
#      72     raise DistutilsExecError(
#      73         f"command {_debug(cmd)!r} failed: {exc.args[-1]}"
#      74     ) from exc
#
# File ~/miniforge3/lib/python3.12/subprocess.py:408, in check_call(*popenargs, **kwargs)
#     398 def check_call(*popenargs, **kwargs):
#     399     """Run command with arguments.  Wait for command to complete.  If
#     400     the exit code was zero then return, otherwise raise
#     401     CalledProcessError.  The CalledProcessError object will have the
#    (...)
#     406     check_call(["ls", "-l"])
#     407     """
# --> 408     retcode = call(*popenargs, **kwargs)
#     409     if retcode:
#     410         cmd = kwargs.get("args")
#
# File ~/miniforge3/lib/python3.12/subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File ~/miniforge3/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/miniforge3/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File ~/miniforge3/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
lumi_results = np.array(lumi_results)
n_macroparticles = lumi_results[:, 0]
n_lumigrid_cells = lumi_results[:, 1]
luminosities = lumi_results[:, 2]

# Normalize luminosities
normalised_lumis = luminosities / analytical_lumi  # Ensures no 0s

# Define log-scaled bins
bins_x = np.logspace(np.log10(n_macroparticles.min()), np.log10(n_macroparticles.max()), 10)
bins_y = np.logspace(np.log10(n_lumigrid_cells.min()), np.log10(n_lumigrid_cells.max()), 10)

# Create the 2D histogram
plt.figure(figsize=(8, 6), facecolor='white')
#plt.gca().set_facecolor("white")

hist, xedges, yedges, img = plt.hist2d(
    n_macroparticles, 
    n_lumigrid_cells, 
    bins=[bins_x, bins_y], 
    weights=normalised_lumis,  # Use normalised values
    cmap="plasma", 
    norm=plt.Normalize(vmin=0.1, vmax=1.5)  # Adjusted scale for visibility
)

hist_masked = np.ma.masked_where(hist == 0, hist)
img.set_array(hist_masked.ravel())


# Add colorbar
cbar = plt.colorbar(img)
cbar.set_label("Normalized Numerical Luminosity (Analytical = 1.0)")

# Set axis labels and scaling
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.title("Fixed Normalized 2D Histogram of Luminosity")
plt.show()

# %%
import scipy as sp
# Define log-scaled bins for your axes
bins_x = np.logspace(np.log10(n_macroparticles.min()), np.log10(n_macroparticles.max()), 10)
bins_y = np.logspace(np.log10(n_lumigrid_cells.min()), np.log10(n_lumigrid_cells.max()), 10)

# Create the 2D histogram with normalised luminosities
plt.figure(figsize=(8, 6), facecolor='white')

hist, xedges, yedges, img = plt.hist2d(
    n_macroparticles, 
    n_lumigrid_cells, 
    bins=[bins_x, bins_y], 
    weights=normalised_lumis,  # Use normalised values
    cmap="Reds",  # Color map with a consistent color that darkens
    norm=plt.Normalize(vmin=0, vmax=1)  # Ensures normalized values are mapped to the color scale
)

#hist_masked = np.ma.masked_where(hist == 0, hist)
# Interpolate the color values for the masked (empty) bins using nearest-neighbor interpolation
# This makes the empty bins take the color of the nearest non-zero bin
#hist_filled = sp.ndimage.distance_transform_edt(np.isnan(hist_masked))  # Interpolating distances

# Fill masked areas with the values from the nearest data points
#hist_filled = np.ma.masked_where(hist == 0, hist_filled)  # Mask the areas where hist was zero

# Set the filled array back to the img's data
#img.set_array(hist_filled.ravel())

# Add colorbar
cbar = plt.colorbar(img)
cbar.set_label("Normalized Numerical Luminosity (Analytical = 1.0)")

# Set axis labels and scaling
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale('log')
plt.yscale('log')
plt.title("Fixed Normalized 2D Histogram of Luminosity")

# Show the plot
plt.show()
print(normalised_lumis)
# Out:
# [0.36275871 0.97907817 0.85532572 0.94455903 0.75380911 0.87026391
#  0.50502407 1.94709866 1.78486139 1.91403094 0.46794853 0.78188365
#  1.11184782 0.98429452 0.94000914 1.36847002 0.79306094 1.08011924
#  1.70477409 1.35767819 0.37847521 0.80751034 1.06030414 0.9565781
#  0.99546313 0.98942852 0.91551751 0.58460089 1.1007664  0.86501538
#  0.3804789  0.78669357 0.83260178 0.95476726 1.03388861 1.00127525
#  1.02567332 1.25766277 0.94882916 0.974482   0.39520348 0.76449496
#  0.96202944 0.9582017  0.95783144 0.99716002 1.00836099 0.992496
#  0.94266622 1.02979762 0.394663   0.82224455 0.93282476 0.98537803
#  0.99656399 0.9835885  0.9166446  0.90610358 1.11479948 1.27575841
#  0.3901687  0.77549642 0.95810459 1.00801602 1.00118254 0.99286293
#  0.98658768 0.96944968 1.03659288 0.96720743 0.38860701 0.78742393
#  0.9678086  0.99196251 0.99821729 0.99711856 0.99909128 1.00067514
#  1.00185981 0.99635291 0.38909215 0.78639235 0.96237065 0.98853564
#  0.99890229 0.99735543 0.99767182 0.99930542 0.9995696  1.00062193
#  0.38966632 0.78552017 0.96269331 0.99048489 0.99728559 1.00044072
#  0.9993247  0.99827631 1.00116359 1.00011945]

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors

# Assuming `lumi_results` is already computed, and `normalised_lumis` is ready.
# Create your histogram as before

# Define bins for the 2D histogram
bins_x = np.logspace(np.log10(n_macroparticles.min()), np.log10(n_macroparticles.max()), 12)
bins_y = np.logspace(np.log10(n_lumigrid_cells.min()), np.log10(n_lumigrid_cells.max()), 12)

# Create the 2D histogram with normalised luminosities
plt.figure(figsize=(8, 6), facecolor='white')

# Plot histogram with the normalized luminosities
hist, xedges, yedges, img = plt.hist2d(
    n_macroparticles, 
    n_lumigrid_cells, 
    bins=[bins_x, bins_y], 
    weights=normalised_lumis,  # Use normalised values
    cmap="Reds",  # Red color map
    norm=plt.Normalize(vmin=0, vmax=1)  # Normalize color scaling
)

# Mask the zero values (empty bins) in the histogram
hist_masked = np.ma.masked_where(hist == 0, hist)

# Now interpolate over the masked (empty) values in the histogram
# Interpolation approach using nearest-neighbor for filling empty bins

# Create an array to store the interpolated histogram values
interpolated_hist = hist.copy()

# Create an index mask to identify non-zero entries
non_zero_mask = hist > 0

# For each empty bin, interpolate from the nearest non-zero bin in both x and y directions
for i in range(1, hist.shape[0] - 1):
    for j in range(1, hist.shape[1] - 1):
        if hist[i, j] == 0:
            # Use the average of the closest non-zero bins around this empty bin
            # Use a 3x3 neighborhood of the current bin for interpolation
            neighborhood = hist[i-1:i+2, j-1:j+2]
            if np.any(neighborhood > 0):  # Only interpolate if there are non-zero neighbors
                interpolated_hist[i, j] = np.mean(neighborhood[neighborhood > 0])

# Update the plot with the interpolated histogram data
img.set_array(interpolated_hist.T)  # Transpose to match the plotting direction

# Add colorbar
cbar = plt.colorbar(img)
cbar.set_label("Normalized Numerical Luminosity (Analytical = 1.0)")

# Set axis labels and scaling
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")
plt.yscale("log")
plt.title("Fixed Normalized 2D Histogram of Luminosity")

# Show the plot
plt.show()

# %%
analytical_lumi = Lumi_analytical(1, bunch_intensity, bunch_intensity, frev, 
                                  0, np.sqrt(physemit_x * beta_x), 
                                  np.sqrt(physemit_x * beta_x), 
                                  np.sqrt(physemit_y * beta_x))
#lumi_results[:, 2] *= analytical_lumi
print(lumi_results)

# normalised_lumis = lumi_results[:, 2] / analytical_lumi
# plt.figure(figsize=(8, 6))
# plt.hist2d(lumi_results[:, 0], lumi_results[:, 1], 
#            weights=normalised_lumis, 
#            bins=(len(n_macroparticles_list), len(n_lumigrid_cells_list)), 
#            cmap='plasma')

# plt.colorbar(label="Normalized Numerical Luminosity (Analytical = 1.0)")
# plt.xlabel("Number of Macroparticles")
# plt.ylabel("Number of Lumi Grid Cells")
# plt.xscale("log")
# plt.yscale("log")
# plt.title("Normalized 2D Histogram of Luminosity")
# plt.show()

# plt.figure(figsize=(8, 6))

# Adjust binning using numpy's logspace for better scaling
bins_x = np.logspace(np.log10(min(n_macroparticles_list)), np.log10(max(n_macroparticles_list)), len(n_macroparticles_list) + 1)
bins_y = np.logspace(np.log10(min(n_lumigrid_cells_list)), np.log10(max(n_lumigrid_cells_list)), len(n_lumigrid_cells_list) + 1)

plt.hist2d(lumi_results[:, 0], lumi_results[:, 1], 
           bins=[bins_x, bins_y], 
           weights=normalised_lumis, 
           cmap='plasma', 
           norm=plt.Normalize(vmin=0, vmax=1.5))  # Adjust vmin/vmax for better contrast

plt.colorbar(label="Normalized Numerical Luminosity (Analytical = 1.0)")
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")
plt.yscale("log")
plt.title("Normalized 2D Histogram of Luminosity")
plt.show()
print(normalised_lumis)

bins_x = np.logspace(np.log10(min(n_macroparticles_list)), np.log10(max(n_macroparticles_list)), 10)  # Increase to 30 bins
bins_y = np.logspace(np.log10(min(n_lumigrid_cells_list)), np.log10(max(n_lumigrid_cells_list)), 10)  

plt.hist2d(lumi_results[:, 0], lumi_results[:, 1], 
           bins=[bins_x, bins_y], 
           weights=normalised_lumis,  # Use normalised_lumis instead!
           cmap='plasma', 
           norm=plt.Normalize(vmin=0, vmax=1.5)) 

plt.colorbar(label="Normalized Numerical Luminosity (Analytical = 1.0)")
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")
plt.yscale("log")
plt.title("Fixed Normalized 2D Histogram of Luminosity")
plt.show()
# Out:
# [[1.00000000e+02 1.00000000e+01 2.84013393e+32]
#  [1.00000000e+02 2.00000000e+01 5.65934632e+32]
#  [1.00000000e+02 5.00000000e+01 6.68472344e+32]
#  [1.00000000e+02 1.00000000e+02 7.87587524e+32]
#  [1.00000000e+02 2.00000000e+02 6.35528888e+32]
#  [1.00000000e+02 5.00000000e+02 9.30162651e+32]
#  [1.00000000e+02 1.00000000e+03 1.64335121e+33]
#  [5.00000000e+02 1.00000000e+01 2.67241068e+32]
#  [5.00000000e+02 2.00000000e+01 5.52301056e+32]
#  [5.00000000e+02 5.00000000e+01 6.42022594e+32]
#  [5.00000000e+02 1.00000000e+02 6.82461940e+32]
#  [5.00000000e+02 2.00000000e+02 6.55958118e+32]
#  [5.00000000e+02 5.00000000e+02 6.35271672e+32]
#  [5.00000000e+02 1.00000000e+03 6.52730271e+32]
#  [1.00000000e+03 1.00000000e+01 2.64169110e+32]
#  [1.00000000e+03 2.00000000e+01 5.44696731e+32]
#  [1.00000000e+03 5.00000000e+01 6.30127442e+32]
#  [1.00000000e+03 1.00000000e+02 6.69997945e+32]
#  [1.00000000e+03 2.00000000e+02 6.63669368e+32]
#  [1.00000000e+03 5.00000000e+02 6.31852173e+32]
#  [1.00000000e+03 1.00000000e+03 6.92897601e+32]
#  [5.00000000e+03 1.00000000e+01 2.66650517e+32]
#  [5.00000000e+03 2.00000000e+01 5.21594952e+32]
#  [5.00000000e+03 5.00000000e+01 6.55077116e+32]
#  [5.00000000e+03 1.00000000e+02 6.59538054e+32]
#  [5.00000000e+03 2.00000000e+02 6.64698116e+32]
#  [5.00000000e+03 5.00000000e+02 6.72049530e+32]
#  [5.00000000e+03 1.00000000e+03 6.76613626e+32]
#  [1.00000000e+05 1.00000000e+01 2.63045374e+32]
#  [1.00000000e+05 2.00000000e+01 5.29729338e+32]
#  [1.00000000e+05 5.00000000e+01 6.49479585e+32]
#  [1.00000000e+05 1.00000000e+02 6.63918509e+32]
#  [1.00000000e+05 2.00000000e+02 6.67424908e+32]
#  [1.00000000e+05 5.00000000e+02 6.72635995e+32]
#  [1.00000000e+05 1.00000000e+03 6.71900539e+32]
#  [5.00000000e+05 1.00000000e+01 2.61033835e+32]
#  [5.00000000e+05 2.00000000e+01 5.27661515e+32]
#  [5.00000000e+05 5.00000000e+01 6.46317693e+32]
#  [5.00000000e+05 1.00000000e+02 6.65903961e+32]
#  [5.00000000e+05 2.00000000e+02 6.70087502e+32]
#  [5.00000000e+05 5.00000000e+02 6.70908990e+32]
#  [5.00000000e+05 1.00000000e+03 6.69774683e+32]
#  [1.00000000e+06 1.00000000e+01 2.61534210e+32]
#  [1.00000000e+06 2.00000000e+01 5.28134534e+32]
#  [1.00000000e+06 5.00000000e+01 6.46746885e+32]
#  [1.00000000e+06 1.00000000e+02 6.65168976e+32]
#  [1.00000000e+06 2.00000000e+02 6.69986722e+32]
#  [1.00000000e+06 5.00000000e+02 6.71267791e+32]
#  [1.00000000e+06 1.00000000e+03 6.72456829e+32]]
# [0.42256238 0.842012   0.99457022 1.17179283 0.94555611 1.38391974
#  2.44501989 0.39760809 0.82172761 0.95521761 1.0153843  0.97595124
#  0.94517341 0.97114876 0.39303755 0.81041371 0.9375197  0.99684005
#  0.98742423 0.9400858  1.03091074 0.39672945 0.77604229 0.97464046
#  0.98127756 0.98895483 0.99989245 1.00668303 0.39136562 0.78814484
#  0.96631231 0.98779491 0.99301182 1.00076501 0.99967078 0.38837281
#  0.78506828 0.96160797 0.99074892 0.9969733  0.99819553 0.99650788
#  0.38911728 0.78577205 0.96224653 0.98965539 0.99682335 0.99872936
#  1.00049844]

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import scipy.interpolate as interp

# Assuming you already have the `lumi_results` data and `normalised_lumis` ready

# Create your histogram as before
bins_x = np.logspace(np.log10(n_macroparticles.min()), np.log10(n_macroparticles.max()), 1000)
bins_y = np.logspace(np.log10(n_lumigrid_cells.min()), np.log10(n_lumigrid_cells.max()), 1000)

# Create the 2D histogram with normalized luminosities
plt.figure(figsize=(8, 6), facecolor='white')

# Create histogram
hist, xedges, yedges, img = plt.hist2d(
    n_macroparticles, 
    n_lumigrid_cells, 
    bins=[bins_x, bins_y], 
    weights=normalised_lumis,  # Use normalized values
    cmap="plasma",  # Red color map
    norm=plt.Normalize(vmin=0, vmax=1)  # Normalize color scaling
)

# Mask the zero values (empty bins) in the histogram
hist_masked = np.ma.masked_where(hist == 0, hist)

# Coordinates of the non-zero bins
x_non_zero, y_non_zero = np.where(hist > 0)

# Coordinates of the empty bins
x_empty, y_empty = np.where(hist == 0)

# Prepare the grid for interpolation
x_grid, y_grid = np.meshgrid(np.arange(hist.shape[1]), np.arange(hist.shape[0]))

# Flatten the grid for interpolation purposes
x_flat = x_grid.flatten()
y_flat = y_grid.flatten()

# Use scipy's griddata to perform interpolation
points = np.array([x_non_zero, y_non_zero]).T  # Non-zero points as (x, y) pairs
values = hist[x_non_zero, y_non_zero]  # Values at the non-zero points

# Perform interpolation for the empty bins
interpolated_values = interp.griddata(points, values, (x_flat, y_flat), method='linear', fill_value=0)

# Reshape the interpolated values back to the 2D grid
hist_interpolated = interpolated_values.reshape(hist.shape)

# Mask any remaining zeros after interpolation
hist_masked = np.ma.masked_where(hist_interpolated == 0, hist_interpolated)

# Update the plot with the filled histogram data
img.set_array(hist_masked.T)  # Transpose to match the plotting direction

# Add colorbar
cbar = plt.colorbar(img)
cbar.set_label("Normalized Numerical Luminosity (Analytical = 1.0)")

# Set axis labels and scaling
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")
plt.yscale("log")
plt.title("LHC 2D Histogram of Luminosity")

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Lumi analytical (replace with actual value)
Lumi_analytical = 6.72456829e+32  # Example value; update if needed

# Extract values from the results table
n_macroparticles = lumi_results[:, 0]
n_lumigrid_cells = lumi_results[:, 1]
luminosities = lumi_results[:, 2]

# Normalize luminosities
normalised_lumis = luminosities / Lumi_analytical  # Ensures no 0s

# Define log-scaled bins
bins_x = np.logspace(np.log10(n_macroparticles.min()), np.log10(n_macroparticles.max()), 10)
bins_y = np.logspace(np.log10(n_lumigrid_cells.min()), np.log10(n_lumigrid_cells.max()), 10)

# Create the 2D histogram
plt.figure(figsize=(8, 6), facecolor='white')
#plt.gca().set_facecolor("white")

hist, xedges, yedges, img = plt.hist2d(
    n_macroparticles, 
    n_lumigrid_cells, 
    bins=[bins_x, bins_y], 
    weights=normalised_lumis,  # Use normalised values
    cmap="plasma", 
    norm=plt.Normalize(vmin=0.1, vmax=1.5)  # Adjusted scale for visibility
)

hist_masked = np.ma.masked_where(hist == 0, hist)
img.set_array(hist_masked.ravel())


# Add colorbar
cbar = plt.colorbar(img)
cbar.set_label("Normalized Numerical Luminosity (Analytical = 1.0)")

# Set axis labels and scaling
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.title("Fixed Normalized 2D Histogram of Luminosity")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import xobjects as xo
import xtrack as xt
import xfieldsdevlumi as xf
import xpart as xp
import time

# ==========================
# Beam and Machine Parameters
# ==========================
n_macroparticles_list = [100, 500, 1000, 5000, 100000, 500000, 1000000]  
n_lumigrid_cells_list = [10, 20, 50, 100, 200, 500, 1000, 2500]

# Storage for results: [n_macroparticles, n_lumigrid_cells, numerical_luminosity]
lumi_results = []

for n_macroparticles in n_macroparticles_list:
    for n_lumigrid_cells in n_lumigrid_cells_list:
        
        # Create CPU Context
        context = xo.ContextCpu(omp_num_threads=8)
        
        # Define LHC beam parameters
        p0c = 6500e9  # Beam energy
        bunch_intensity = 0.7825E11
        physemit_x = (2.946E-6*xp.PROTON_MASS_EV)/p0c 
        physemit_y = (2.946E-6*xp.PROTON_MASS_EV)/p0c 
        beta_x = 19.17
        beta_y = 19.17
        sigma_z = 0.08
        sigma_delta = 1E-4
        beta_s = sigma_z/sigma_delta
        Qx = 64.31
        Qy = 59.32
        Qs = 2.1E-3
        frev = 11245  # Corrected Revolution Frequency
        nTurn = 3

        pipeline_manager = xt.PipelineManager()
        pipeline_manager.add_particles('b1', 0)
        pipeline_manager.add_particles('b2', 0)
        pipeline_manager.add_element('IP1')
        pipeline_manager.add_element('IP2')

        # Generate particle distributions
        particles_b1 = xp.Particles(
            _context=context,
            p0c=p0c,
            x=np.sqrt(physemit_x*beta_x)*(np.random.randn(n_macroparticles)),
            px=np.sqrt(physemit_x/beta_x)*np.random.randn(n_macroparticles),
            y=np.sqrt(physemit_y*beta_y)*(np.random.randn(n_macroparticles)),
            py=np.sqrt(physemit_y/beta_y)*np.random.randn(n_macroparticles),
            zeta=sigma_z*np.random.randn(n_macroparticles),
            delta=sigma_delta*np.random.randn(n_macroparticles),
            weight=bunch_intensity/n_macroparticles
        )
        particles_b1.init_pipeline('b1')
        particles_b2 = particles_b1.copy()
        particles_b2.init_pipeline('b2')

        # Configure Beam-Beam Elements
        slicer = xf.TempSlicer(sigma_z=sigma_z, n_slices=1, mode='shatilov')
        config_for_update_b1 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
            pipeline_manager=pipeline_manager, element_name='IP1', partner_particles_name='b2', slicer=slicer, update_every=1)
        config_for_update_b2 = xf.ConfigForUpdateBeamBeamBiGaussian3D(
            pipeline_manager=pipeline_manager, element_name='IP1', partner_particles_name='b1', slicer=slicer, update_every=1)

        # Define Beam-Beam Interaction Elements
        bbeam_b1 = xf.BeamBeamBiGaussian3D(
            _context=context, other_beam_q0=particles_b2.q0, phi=0, alpha=0, config_for_update=config_for_update_b1,
            flag_numerical_luminosity=1, flag_luminosity=1, n_lumigrid_cells=n_lumigrid_cells,
            sig_lumigrid_cells=np.sqrt(physemit_x*beta_x), range_lumigrid_cells=24,
            n_macroparticles=n_macroparticles, nTurn=nTurn, update_lumigrid_sum=1)

        bbeam_b2 = bbeam_b1.copy()

        # Arc segment (tracking through lattice)
        arc = xt.LineSegmentMap(betx=beta_x, bety=beta_y, qx=Qx/2, qy=Qy/2, bets=beta_s, qs=Qs)

        # Create tracking lines
        line_b1 = xt.Line(elements=[bbeam_b1, arc])
        line_b2 = xt.Line(elements=[bbeam_b2, arc])
        line_b1.build_tracker()
        line_b2.build_tracker()

        # Define Tracking Pipeline
        branch_b1 = xt.PipelineBranch(line_b1, particles_b1)
        branch_b2 = xt.PipelineBranch(line_b2, particles_b2)
        multitracker = xt.PipelineMultiTracker(branches=[branch_b1, branch_b2])

        # Start Internal Logging Before Tracking
        record_qss_b1 = line_b1.start_internal_logging_for_elements_of_type(
            xf.BeamBeamBiGaussian3D, capacity={"lumitable": nTurn, "numlumitable": nTurn}
        )

        # Perform Tracking
        print(f"Tracking: n_macroparticles={n_macroparticles}, n_lumigrid_cells={n_lumigrid_cells}...")
        time0 = time.time()
        multitracker.track(num_turns=nTurn, turn_by_turn_monitor=True)
        print('Done tracking in', (time.time()-time0) / nTurn, '[s/turn]')

        # Stop Logging and Move Data to CPU
        line_b1.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)
        record_qss_b1.move(_context=xo.context_default)

        # Retrieve Luminosity Data
        num_lumi_b1_beambeam = np.array(bbeam_b1.numlumitable.numerical_luminosity)

        # Store Results for 2D Histogram
        lumi_results.append([n_macroparticles, n_lumigrid_cells, num_lumi_b1_beambeam[0]])

# Convert to Numpy Array for Plotting
lumi_results = np.array(lumi_results)

# ==========================
# 2D Histogram Visualization
# ==========================
plt.figure(figsize=(8, 6))
plt.hist2d(lumi_results[:, 0], lumi_results[:, 1], weights=lumi_results[:, 2], 
           bins=(len(n_macroparticles_list), len(n_lumigrid_cells_list)), cmap='plasma')

plt.colorbar(label="Numerical Luminosity")
plt.xlabel("Number of Macroparticles")
plt.ylabel("Number of Lumi Grid Cells")
plt.xscale("log")  
plt.yscale("log")  
plt.title("2D Histogram of Luminosity vs Macroparticles & Lumi Grid Cells")
plt.show()
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# 7b6c7750fac74ffc936cade075ff5101.c:11208:11: warning: '_GNU_SOURCE' macro redefined [-Wmacro-redefined]
#  11208 | #  define _GNU_SOURCE // enable GNU libc NAN extension if possible
#        |           ^
# /Users/arizakhtar/miniforge3/include/python3.12/pyconfig.h:1723:10: note: previous definition is here
#  1723 | # define _GNU_SOURCE 1
#       |          ^
# 1 warning generated.
# Done compiling ContextCpu kernels.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 89
#      87 # Define Tracking Pipeline
#      88 branch_b1 = xt.PipelineBranch(line_b1, particles_b1)
# ---> 89 branch_b2 = xt.PipelineBranch(line_b2, particles_b2)
#      90 multitracker = xt.PipelineMultiTracker(branches=[branch_b1, branch_b2])
#      92 # Start Internal Logging Before Tracking
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/pipeline/multitracker.py:26, in PipelineBranch.__init__(self, line, particles, tracker)
#      23 if self.line.tracker is None:
#      24     raise ValueError('Tracker not built for line')
# ---> 26 self.line.tracker.enable_pipeline_hold = True
#
# File ~/miniforge3/lib/python3.12/site-packages/xtrack/tracker.py:414, in Tracker.enable_pipeline_hold(self, value)
#     411 @enable_pipeline_hold.setter
#     412 def enable_pipeline_hold(self, value):
#     413     if not self.iscollective:
# --> 414         raise ValueError(
#     415             'enable_pipeline_hold is not supported non collective trackers')
#     416     else:
#     417         self._enable_pipeline_hold = value
#
# ValueError: enable_pipeline_hold is not supported non collective trackers
